# %%
# Student Dropout Prediction using a Gated Graph Attention Network (GAT)

Author:
Rabbi Perez
Cornelius Anokye
Andy Adu Nyarko
Jeremiah Nartey
Kwesi Nkansah Ataara

Institution:
Kwame Nkrumah University of Science and Technology

Project:
Final Year Project

Version:
1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_855/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# --> 272       raise ValueError('mount failed' + extra_reason)
# ...

# %%
import os
import random
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch

warnings.filterwarnings("ignore")

# %%
PROJECT_DIR = "/content/drive/MyDrive/Dropout-Prediction-GAT"

RAW_DATA = os.path.join(PROJECT_DIR, "data", "raw")
PROCESSED_DATA = os.path.join(PROJECT_DIR, "data", "processed")

MODELS = os.path.join(PROJECT_DIR, "models")
OUTPUTS = os.path.join(PROJECT_DIR, "output")
DOCS = os.path.join(PROJECT_DIR, "docs")

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Device:", device)
# Out:
# Device: cpu

# %%
print("Pandas :", pd.__version__)
print("NumPy  :", np.__version__)
print("PyTorch:", torch.__version__)
# Out:
# Pandas : 2.2.2
# NumPy  : 2.0.2
# PyTorch: 2.11.0+cpu

# %%
folders = [
    RAW_DATA,
    PROCESSED_DATA,
    MODELS,
    OUTPUT,
    DOCS
]

for folder in folders:
    print(folder, "Exists" if os.path.exists(folder) else "Missing")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1285/3333790092.py in <cell line: 0>()
#       3     PROCESSED_DATA,
#       4     MODELS,
# ----> 5     OUTPUT,
#       6     DOCS
#       7 ]
#
# NameError: name 'OUTPUT' is not defined

# %%
folders = [
    RAW_DATA,
    PROCESSED_DATA,
    MODELS,
    OUTPUTS,
    DOCS
]

for folder in folders:
    print(folder, "Exists" if os.path.exists(folder) else "Missing")
# Out:
# /content/drive/MyDrive/Dropout-Prediction-GAT/data/raw Missing
# /content/drive/MyDrive/Dropout-Prediction-GAT/data/processed Missing
# /content/drive/MyDrive/Dropout-Prediction-GAT/models Missing
# /content/drive/MyDrive/Dropout-Prediction-GAT/output Missing
# /content/drive/MyDrive/Dropout-Prediction-GAT/docs Missing

# %%
print("=" * 50)
print("Environment Ready")
print("=" * 50)
# Out:
# ...
# Environment Ready
# ...
